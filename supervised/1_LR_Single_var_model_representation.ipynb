# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train=np.array([1.0, 2.0])
y_train=np.array([300.0, 500.0])
print(f"x_train= {x_train}")
print(f"y_train= {y_train}")
# Out:
# x_train= [1. 2.]
# y_train= [300. 500.]

# %%
# m is the number of training examples
print(f"x_train.shape: {x_train.shape}")
m=x_train.shape[0]
print(f"Number of training examples is: {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is: 2

# %%
#m is the number of trainign examples
m=len(x_train)
print(f"Number of training examples is: {m}")
# Out:
# Number of training examples is: 2

# %%
i=0

x_i=x_train[i]
y_i=y_train[i]
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %%
#plot the data points
plt.scatter(x_train, y_train, marker='x', c='r')
# set the title
plt.title("Housing Prices")
# set the y-axis label
plt.ylabel('price (in 1000s of dollars)')
# set the x-axis label
plt.xlabel('size (1000 sq.ft)')
plt.show()

# %%
w=100
b=100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %%
def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples 
      w,b (scalar)    : model parameters  
    Returns
      f_wb (ndarray (m,)): model prediction
    """
    m=x.shape[0]
    f_wb=np.zeros(m) #creates a 1d numpy array with m entries.
    for i in range(m):
        f_wb[i]=x[i]*w+b
    return f_wb

# %% [markdown]
# let's compute the compute_model_output function and plot the output

# %%
hehe_f_wb=compute_model_output(x_train, w,b)

# plot our model prediction
plt.plot(x_train, hehe_f_wb, c='b', label='our prediction')

# plot the data points
plt.scatter(x_train, y_train, marker='x' , c='r' , label='Actual values')

# set the title
plt.title('Housing Prices')

# set the x_label
plt.xlabel('size (in 1000sq.ft)')

# set the y_label
plt.ylabel('prices (in 1000$)')

plt.legend()
plt.show()

# %%
w=200
b=100
x_i=1.2
cost_1200sqft=w*x_i+b

print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $340 thousand dollars
